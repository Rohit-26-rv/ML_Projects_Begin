# %% [markdown]
# # MNIST Test_1

# %%
# !pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in d:\ml projects\py3-tf2.0\lib\site-packages (4.9.9)
# Requirement already satisfied: absl-py in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (2.3.1)
# Requirement already satisfied: dm-tree in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in d:\ml projects\py3-tf2.0\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.13.0)
# Requirement already satisfied: immutabledict in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (4.2.2)
# Requirement already satisfied: numpy in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (2.3.4)
# Requirement already satisfied: promise in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (6.33.0)
# Requirement already satisfied: psutil in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (7.1.3)
# Requirement already satisfied: pyarrow in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (22.0.0)
# Requirement already satisfied: requests>=2.19.0 in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (2.32.5)
# Requirement already satisfied: simple_parsing in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: termcolor in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (3.2.0)
# Requirement already satisfied: toml in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-datasets) (2.0.0)
# Requirement already satisfied: einops in d:\ml projects\py3-tf2.0\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in d:\ml projects\py3-tf2.0\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.10.0)
# Requirement already satisfied: importlib_resources in d:\ml projects\py3-tf2.0\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in d:\ml projects\py3-tf2.0\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.15.0)
# Requirement already satisfied: zipp in d:\ml projects\py3-tf2.0\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ml projects\py3-tf2.0\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\ml projects\py3-tf2.0\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ml projects\py3-tf2.0\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ml projects\py3-tf2.0\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2025.10.5)
# Requirement already satisfied: attrs>=18.2.0 in d:\ml projects\py3-tf2.0\lib\site-packages (from dm-tree->tensorflow-datasets) (25.4.0)
# Requirement already satisfied: six in d:\ml projects\py3-tf2.0\lib\site-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in d:\ml projects\py3-tf2.0\lib\site-packages (from simple_parsing->tensorflow-datasets) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in d:\ml projects\py3-tf2.0\lib\site-packages (from tensorflow-metadata->tensorflow-datasets) (1.71.0)
# Requirement already satisfied: colorama in d:\ml projects\py3-tf2.0\lib\site-packages (from tqdm->tensorflow-datasets) (0.4.6)

# %%
import numpy as np
import tensorflow as tf

import tensorflow_datasets as tfds

# %%
# with_info = True >> this provide tuple with info about version, feature and number of samples of the dataset
# as_supervised = True >> this give tuple (input, target)

mnist_dataset, mnist_info = tfds.load(name='mnist', with_info= True, as_supervised= True)

# extract train and test data
mnist_train, mnist_test = mnist_dataset['train'], mnist_dataset['test']

# validation data
num_validation_samples = 0.1 * mnist_info.splits['train'].num_examples
num_validation_samples = tf.cast(num_validation_samples, tf.int64)

num_test_samples = mnist_info.splits['test'].num_examples
num_test_samples = tf.cast(num_test_samples, tf.int64)

def scale(image, label):
    image = tf.cast(image, tf.float32)
    image /= 255
    return image, label

scaled_train_and_validation_data = mnist_train.map(scale)

test_data = mnist_test.map(scale)

# shuffling

buffer_size = 10000
shuffle_train_and_validation_data = scaled_train_and_validation_data.shuffle(buffer_size)

validation_data = shuffle_train_and_validation_data.take(num_validation_samples)
train_data = shuffle_train_and_validation_data.skip(num_validation_samples)


batch_size = 100

train_data = train_data.batch(batch_size)
validation_data = validation_data.batch(num_validation_samples)
test_data = test_data.batch(num_test_samples)

validation_inputs, validation_targets = next(iter(validation_data))

# %%
# Outline Model

input_size = 784
output_size = 10
hidden_layer_size = 50

model = tf.keras.Sequential([
                            tf.keras.layers.Flatten(input_shape= (28,28,1)),
                            tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                            tf.keras.layers.Dropout(0.3),
                            tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                            tf.keras.layers.Dropout(0.3),
                            tf.keras.layers.Dense(output_size, activation='softmax'),
])
# Out:
# d:\ML Projects\py3-TF2.0\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# optimizer and loss

model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Trainings

num_epoch = 10

model.fit(train_data, epochs= num_epoch, validation_data= (validation_inputs, validation_targets), verbose = 2)
# Out:
# Epoch 1/10
# 540/540 - 3s - 6ms/step - accuracy: 0.7734 - loss: 0.7161 - val_accuracy: 0.9228 - val_loss: 0.2605
# Epoch 2/10
# 540/540 - 2s - 5ms/step - accuracy: 0.8922 - loss: 0.3670 - val_accuracy: 0.9378 - val_loss: 0.2000
# Epoch 3/10
# 540/540 - 3s - 5ms/step - accuracy: 0.9096 - loss: 0.3079 - val_accuracy: 0.9505 - val_loss: 0.1720
# Epoch 4/10
# 540/540 - 3s - 5ms/step - accuracy: 0.9211 - loss: 0.2729 - val_accuracy: 0.9580 - val_loss: 0.1494
# Epoch 5/10
# 540/540 - 2s - 3ms/step - accuracy: 0.9276 - loss: 0.2484 - val_accuracy: 0.9620 - val_loss: 0.1336
# Epoch 6/10
# 540/540 - 4s - 7ms/step - accuracy: 0.9334 - loss: 0.2294 - val_accuracy: 0.9633 - val_loss: 0.1269
# Epoch 7/10
# 540/540 - 4s - 7ms/step - accuracy: 0.9365 - loss: 0.2180 - val_accuracy: 0.9652 - val_loss: 0.1182
# Epoch 8/10
# 540/540 - 4s - 7ms/step - accuracy: 0.9380 - loss: 0.2087 - val_accuracy: 0.9667 - val_loss: 0.1131
# Epoch 9/10
# 540/540 - 4s - 7ms/step - accuracy: 0.9419 - loss: 0.1980 - val_accuracy: 0.9692 - val_loss: 0.1073
# Epoch 10/10
# 540/540 - 4s - 7ms/step - accuracy: 0.9420 - loss: 0.1938 - val_accuracy: 0.9707 - val_loss: 0.1005

# %%
test_loss, test_accu = model.evaluate(test_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9641 - loss: 0.1192

# %%
print(f'Test Loss: {round(test_loss,2)}')
print(f'Test Accuracy: {round(test_accu*100,2)}%')
# Out:
# Test Loss: 0.12
# Test Accuracy: 96.41%
